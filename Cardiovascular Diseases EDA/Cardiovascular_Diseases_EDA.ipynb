# %% [markdown]
# # Cardiovascular Diseases EDA
#
# Dataset link :  [click_here](https://www.kaggle.com/datasets/alphiree/cardiovascular-diseases-risk-prediction-dataset)
#
#
# BRFSS Dataset :
#
# The Behavioral Risk Factor Surveillance System (BRFSS) is the nation’s premier system of health-related telephone surveys that collect state data about U.S. residents regarding their health-related risk behaviors, chronic health conditions, and use of preventive services.

# %% [markdown]
# ### Importing dependencies

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
plt.style.use('ggplot')
custom=['#F24C3D','#F2BE22','#22A699','#84A7A1',"#FF8551"]

# %%
Cardiovascular_diseases=pd.read_csv('CVD_cleaned.csv')
Cardiovascular_diseases.head()
# Out:
#   General_Health                  Checkup Exercise Heart_Disease Skin_Cancer  \
# 0           Poor  Within the past 2 years       No            No          No
# 1      Very Good     Within the past year       No           Yes          No
# 2      Very Good     Within the past year      Yes            No          No
# 3           Poor     Within the past year      Yes           Yes          No
# 4           Good     Within the past year       No            No          No
#
#   Other_Cancer Depression Diabetes Arthritis     Sex Age_Category  \
# 0           No         No       No       Yes  Female        70-74
# 1           No         No      Yes        No  Female        70-74
# 2           No         No      Yes        No  Female        60-64
# 3           No         No      Yes        No    Male        75-79
# 4           No         No       No        No    Male          80+
#
#    Height_(cm)  Weight_(kg)    BMI Smoking_History  Alcohol_Consumption  \
# ...

# %%
Cardiovascular_diseases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308854 entries, 0 to 308853
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count   Dtype
# ---  ------                        --------------   -----
#  0   General_Health                308854 non-null  object
#  1   Checkup                       308854 non-null  object
#  2   Exercise                      308854 non-null  object
#  3   Heart_Disease                 308854 non-null  object
#  4   Skin_Cancer                   308854 non-null  object
#  5   Other_Cancer                  308854 non-null  object
#  6   Depression                    308854 non-null  object
#  7   Diabetes                      308854 non-null  object
#  8   Arthritis                     308854 non-null  object
#  9   Sex                           308854 non-null  object
#  10  Age_Category                  308854 non-null  object
#  11  Height_(cm)                   308854 non-null  float64
# ...

# %%
Cardiovascular_diseases.shape
# Out:
# (308854, 19)

# %%
Cardiovascular_diseases.describe()
# Out:
#          Height_(cm)    Weight_(kg)            BMI  Alcohol_Consumption  \
# count  308854.000000  308854.000000  308854.000000        308854.000000
# mean      170.615249      83.588655      28.626211             5.096366
# std        10.658026      21.343210       6.522323             8.199763
# min        91.000000      24.950000      12.020000             0.000000
# 25%       163.000000      68.040000      24.210000             0.000000
# 50%       170.000000      81.650000      27.440000             1.000000
# 75%       178.000000      95.250000      31.850000             6.000000
# max       241.000000     293.020000      99.330000            30.000000
#
#        Fruit_Consumption  Green_Vegetables_Consumption  \
# count      308854.000000                 308854.000000
# mean           29.835200                     15.110441
# std            24.875735                     14.926238
# min             0.000000                      0.000000
# ...

# %% [markdown]
# ### Preparation

# %%
# copy data
df=Cardiovascular_diseases.copy()

# %%
df.duplicated().sum()
# Out:
# 80

# %%
# Drop duplicates
df.drop_duplicates(inplace=True)

# %%
df.isnull().sum()  #There is no null value
# Out:
# The history saving thread hit an unexpected error (OperationalError('disk I/O error')).History will not be written to the database.
# General_Health                  0
# Checkup                         0
# Exercise                        0
# Heart_Disease                   0
# Skin_Cancer                     0
# Other_Cancer                    0
# Depression                      0
# Diabetes                        0
# Arthritis                       0
# Sex                             0
# Age_Category                    0
# Height_(cm)                     0
# Weight_(kg)                     0
# BMI                             0
# Smoking_History                 0
# Alcohol_Consumption             0
# Fruit_Consumption               0
# Green_Vegetables_Consumption    0
# FriedPotato_Consumption         0
# dtype: int64

# %%
df.dtypes
# Out:
# General_Health                   object
# Checkup                          object
# Exercise                         object
# Heart_Disease                    object
# Skin_Cancer                      object
# Other_Cancer                     object
# Depression                       object
# Diabetes                         object
# Arthritis                        object
# Sex                              object
# Age_Category                     object
# Height_(cm)                     float64
# Weight_(kg)                     float64
# BMI                             float64
# Smoking_History                  object
# Alcohol_Consumption             float64
# Fruit_Consumption               float64
# Green_Vegetables_Consumption    float64
# FriedPotato_Consumption         float64
# dtype: object

# %% [markdown]
# ### Data Exploration

# %%
cat_df=df.select_dtypes(include = "object") # categorical variables
num_df=df.select_dtypes(include=["int64","float64"]) # Numerical variables

# %% [markdown]
# ### Categorical Data

# %%
for column in cat_df.columns:
    plt.figure(figsize=(10,5))
    sns.countplot(y=column,data=cat_df)
    plt.title(column)
    plt.show()

# %% [markdown]
# ### Numerical data

# %%
sns.pairplot(data=num_df)
plt.show()

# %%
num_corr=num_df.corr()
plt.figure(figsize=(10,5))
sns.heatmap(data=num_corr,annot=True)
plt.show()

# %% [markdown]
# #### Category
# * The dataset contain more about healthier person data
# * The age category has distributed normal
# * Smoking history about 125000 person
# * Gender : Female are higher about 20000 person then male
#
# #### Correlated
# * BMI and Weight are causation not correlated
# * Weight height correlated
# * Fruit_consumption and Green vegetables correlated

# %% [markdown]
# ## ASK Question and Answer it

# %% [markdown]
# ### 1. What is the distribution of heart disease among the individuals in the dataset?

# %%
heart_disease_distribution = df['Heart_Disease'].value_counts()



plt.bar(heart_disease_distribution.index,heart_disease_distribution.values,color=custom[1:3])
plt.title('Distribution of Heart Disease')
plt.show()

# %% [markdown]
# * Heart Disease are way less than from overall

# %% [markdown]
# ### How many people in the dataset have a history of smoking?

# %%
smoking_history_counts = df['Smoking_History'].value_counts()

# Counting the number of people with a history of smoking
smokers_count = smoking_history_counts['Yes']

# Counting the number of people without a history of smoking
non_smokers_count = smoking_history_counts['No']

# Plotting the counts
plt.bar(['Smokers', 'Non-Smokers'], [smokers_count, non_smokers_count],color=custom[1:3])
plt.xlabel('Smoking History')
plt.ylabel('Count')
plt.title('Number of People with Smoking History')
plt.show()

# %% [markdown]
# * 45%  are Smokers only (125000)

# %% [markdown]
# ### Is there a correlation between BMI and the risk of skin cancer?

# %%
# Plotting the relationship between BMI and the risk of skin cancer
sns.scatterplot(data=df,x='BMI',y='Skin_Cancer')
plt.xlabel('BMI')
plt.ylabel('Skin Cancer Risk')
plt.title('BMI vs Skin Cancer Risk (Correlation:')
plt.show()

# %% [markdown]
# ### What is the most common age category in the dataset?

# %%
Age_cat=df['Age_Category'].value_counts(sort=True).rename_axis('Age_category').reset_index(name='counts').sort_values('Age_category')


#plot
plt.figure(figsize=(10,5))
sns.barplot(data=Age_cat,x='Age_category',y='counts')
plt.title('Most common Age_category')
plt.show()

# %% [markdown]
# * Age_range 18-80+
# * 50-75 are most common Age in the given data

# %% [markdown]
# #### Are there any correlations between height, weight, and the risk of arthritis?

# %%
data=df[['Height_(cm)', 'Weight_(kg)', 'Arthritis']]

#Plot
plt.figure(figsize=(10,5))
sns.scatterplot(data=data,x='Height_(cm)',y='Weight_(kg)',hue='Arthritis')
plt.title('Are ther any correlations ?')
plt.show()

# %% [markdown]
# All over weight and height has Athritis disease not in specific region

# %% [markdown]
# #### Is there any association between fried potato consumption and BMI ?

# %%
data = df[['FriedPotato_Consumption', 'BMI']]

#Plot
plt.figure(figsize=(10,5))
sns.scatterplot(data=data,x='FriedPotato_Consumption',y='BMI')
plt.title('Are ther any Association ?')
plt.show()

# %% [markdown]
#  Consumption of Fired Potato does  increace BMI

# %% [markdown]
# #### Are there any correlations between Alcohol_Consumption, BMI, and Diabetes  ?

# %%
data=df[['Alcohol_Consumption','BMI','Diabetes']]
#Plot
plt.figure(figsize=(10,5))
sns.scatterplot(data=data,x=data['Alcohol_Consumption'],y=data['BMI'],hue=data['Diabetes'])
plt.title('Are ther any correlations ?')
plt.show()
# Out:
# c:\Users\Dana\AppData\Local\Programs\Python\Python311\Lib\site-packages\IPython\core\pylabtools.py:152: UserWarning: Creating legend with loc="best" can be slow with large amounts of data.
#   fig.canvas.print_figure(bytes_io, **kw)

# %% [markdown]
# There is no relationship

# %% [markdown]
# #### Finale Note
#
# * Dataset contain Imbalance data
# * Heart Disease data are lower approximately 5%
